# %%
customer_data = [
    (1, "Ola", "Dublin"),
    (2, "Jane", "Cork"),
    (3, "John", "Galway")
]

columns = [
    "customer_id",
    "customer_name",
    "city"
]

df = spark.createDataFrame(customer_data, columns)

display(df)
